# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from scipy.stats import linregress
from api_keys import weather_api_key
# !pip install citipy
from citipy import citipy
import numpy as np
# Access maps with unique API key
cities_df=pd.DataFrame({"longitude":(np.random.uniform(-1.8,1.8,1200)*100), "latitude":(np.random.uniform(-0.9,0.9,1200)*100)})
cities_df.head()
cities = []
for i in range(0,len(cities_df['latitude'])):
    lat_one=cities_df.iloc[i]['latitude']
    long_one=cities_df.iloc[i]["longitude"]
    city=citipy.nearest_city(lat_one,long_one)
    name=city.city_name
    cities.append(name)
new_cities = []
for x in cities:
    if x not in new_cities:
        new_cities.append(x)
print(len(new_cities))
# Out:
# Requirement already satisfied: citipy in c:\users\esthe\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\esthe\anaconda3\lib\site-packages (from citipy) (0.16)
# 533

# %% [markdown]
# ## Generate Cities List

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lat = []
lng = []
max_temp = []
humidity =[]
cloudiness = []
wind_speed = []
country = []
date = []
print("Beginning Data Retrieval")
print("-----------------------------")
count = 1
new_cities_there = []
for city in new_cities:
    response = requests.get(query_url + city).json()
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        print("Processing Record " + str(count) + " of Set 1 | " + city)
        count += 1
        new_cities_there.append(city)
    except KeyError:
        print("Cannot find the following city: " + city)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | karratha
# Processing Record 2 of Set 1 | coahuayana
# Processing Record 3 of Set 1 | grindavik
# Processing Record 4 of Set 1 | inhambane
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | coquimbo
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | quatre cocos
# Cannot find the following city: nizhneyansk
# Processing Record 10 of Set 1 | san policarpo
# Cannot find the following city: barentsburg
# Processing Record 11 of Set 1 | agadez
# Processing Record 12 of Set 1 | klaksvik
# Cannot find the following city: sentyabrskiy
# Processing Record 13 of Set 1 | san cristobal
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | nouadhibou
# Processing Record 16 of Set 1 | yanam
# Processing Record 17 of Set 1 | faanui
# Cannot find the following city: samusu
# Processing Record 18 of Set 1 | la roda
# Cannot find the following city: taolanaro
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | razdolinsk
# Processing Record 22 of Set 1 | inuvik
# Processing Record 23 of Set 1 | meulaboh
# Processing Record 24 of Set 1 | oskemen
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | port hueneme
# Processing Record 27 of Set 1 | islamkot
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | eirunepe
# Processing Record 30 of Set 1 | pangoa
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | gobabis
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | san vicente
# Processing Record 37 of Set 1 | mount isa
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | brodokalmak
# Processing Record 40 of Set 1 | merauke
# Cannot find the following city: illoqqortoormiut
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | manggar
# Processing Record 43 of Set 1 | bom jesus
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | portland
# Processing Record 46 of Set 1 | hualmay
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | bella union
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | yerofey pavlovich
# Processing Record 51 of Set 1 | skelleftea
# Processing Record 52 of Set 1 | fort nelson
# Processing Record 53 of Set 1 | asau
# Processing Record 54 of Set 1 | mount gambier
# Processing Record 55 of Set 1 | khorixas
# Processing Record 56 of Set 1 | kavaratti
# Processing Record 57 of Set 1 | dobryanka
# Processing Record 58 of Set 1 | new norfolk
# Processing Record 59 of Set 1 | batagay
# Processing Record 60 of Set 1 | ensley
# Processing Record 61 of Set 1 | yulara
# Processing Record 62 of Set 1 | padang
# Processing Record 63 of Set 1 | beringovskiy
# Processing Record 64 of Set 1 | launceston
# Processing Record 65 of Set 1 | sanchor
# Cannot find the following city: cazaje
# Processing Record 66 of Set 1 | punta arenas
# Processing Record 67 of Set 1 | hermanus
# Processing Record 68 of Set 1 | houma
# Processing Record 69 of Set 1 | ribeira grande
# Processing Record 70 of Set 1 | saint-philippe
# Processing Record 71 of Set 1 | yellowknife
# Processing Record 72 of Set 1 | constitucion
# Processing Record 73 of Set 1 | nikolskoye
# Processing Record 74 of Set 1 | puerto ayora
# Processing Record 75 of Set 1 | bredasdorp
# Processing Record 76 of Set 1 | cape town
# Processing Record 77 of Set 1 | tangjiazhuang
# Processing Record 78 of Set 1 | jacareacanga
# Cannot find the following city: saleaula
# Processing Record 79 of Set 1 | sayyan
# Processing Record 80 of Set 1 | jamestown
# Processing Record 81 of Set 1 | atuona
# Processing Record 82 of Set 1 | rikitea
# Processing Record 83 of Set 1 | carnarvon
# Cannot find the following city: longlac
# Processing Record 84 of Set 1 | aykhal
# Processing Record 85 of Set 1 | castro
# Processing Record 86 of Set 1 | tasiilaq
# Cannot find the following city: ruatoria
# Processing Record 87 of Set 1 | port elizabeth
# Processing Record 88 of Set 1 | nova petropolis
# Processing Record 89 of Set 1 | verkhnetulomskiy
# Processing Record 90 of Set 1 | lompoc
# Processing Record 91 of Set 1 | riviere-au-renard
# Processing Record 92 of Set 1 | la palma
# Processing Record 93 of Set 1 | kuloy
# Cannot find the following city: belushya guba
# Processing Record 94 of Set 1 | honningsvag
# Processing Record 95 of Set 1 | upernavik
# Cannot find the following city: malwan
# Processing Record 96 of Set 1 | ravar
# Processing Record 97 of Set 1 | cabo san lucas
# Processing Record 98 of Set 1 | ampanihy
# Processing Record 99 of Set 1 | rawson
# Processing Record 100 of Set 1 | abu samrah
# Processing Record 101 of Set 1 | saint george
# Processing Record 102 of Set 1 | tamworth
# Processing Record 103 of Set 1 | nhamunda
# Processing Record 104 of Set 1 | corato
# Processing Record 105 of Set 1 | livingstonia
# Processing Record 106 of Set 1 | oussouye
# Processing Record 107 of Set 1 | bria
# Processing Record 108 of Set 1 | ciparay
# Processing Record 109 of Set 1 | saskylakh
# Processing Record 110 of Set 1 | qaanaaq
# Processing Record 111 of Set 1 | hilo
# Processing Record 112 of Set 1 | moyobamba
# Processing Record 113 of Set 1 | bonthe
# Processing Record 114 of Set 1 | nanortalik
# Processing Record 115 of Set 1 | bengkulu
# Processing Record 116 of Set 1 | georgetown
# Processing Record 117 of Set 1 | ancud
# Processing Record 118 of Set 1 | marsaxlokk
# Processing Record 119 of Set 1 | namibe
# Processing Record 120 of Set 1 | necochea
# Processing Record 121 of Set 1 | shitkino
# Processing Record 122 of Set 1 | touros
# Processing Record 123 of Set 1 | kahului
# Processing Record 124 of Set 1 | palana
# Processing Record 125 of Set 1 | maniitsoq
# Processing Record 126 of Set 1 | kavieng
# Processing Record 127 of Set 1 | byron bay
# Cannot find the following city: attawapiskat
# Processing Record 128 of Set 1 | sitka
# Processing Record 129 of Set 1 | koroni
# Processing Record 130 of Set 1 | sao filipe
# Processing Record 131 of Set 1 | tiksi
# Processing Record 132 of Set 1 | lubango
# Processing Record 133 of Set 1 | leningradskiy
# Processing Record 134 of Set 1 | hargeysa
# Processing Record 135 of Set 1 | pevek
# Processing Record 136 of Set 1 | kimberley
# Processing Record 137 of Set 1 | longyearbyen
# Cannot find the following city: kawana waters
# Processing Record 138 of Set 1 | bluff
# Processing Record 139 of Set 1 | alipur
# Processing Record 140 of Set 1 | streletskoye
# Processing Record 141 of Set 1 | jega
# Processing Record 142 of Set 1 | hameenlinna
# Processing Record 143 of Set 1 | dzaoudzi
# Processing Record 144 of Set 1 | praia da vitoria
# Processing Record 145 of Set 1 | arraial do cabo
# Processing Record 146 of Set 1 | lavrentiya
# Processing Record 147 of Set 1 | tuktoyaktuk
# Processing Record 148 of Set 1 | ambon
# Processing Record 149 of Set 1 | shimoda
# Processing Record 150 of Set 1 | lebu
# Processing Record 151 of Set 1 | alpena
# Processing Record 152 of Set 1 | bonavista
# Cannot find the following city: satitoa
# Processing Record 153 of Set 1 | urumqi
# Processing Record 154 of Set 1 | auki
# Processing Record 155 of Set 1 | mar del plata
# Processing Record 156 of Set 1 | port alfred
# Processing Record 157 of Set 1 | verkhnyaya inta
# Processing Record 158 of Set 1 | comacchio
# Processing Record 159 of Set 1 | hofn
# Processing Record 160 of Set 1 | fortuna
# Processing Record 161 of Set 1 | sokoni
# Processing Record 162 of Set 1 | uglegorsk
# Processing Record 163 of Set 1 | pyinmana
# Processing Record 164 of Set 1 | mujiayingzi
# Processing Record 165 of Set 1 | kaitangata
# Processing Record 166 of Set 1 | linhai
# Processing Record 167 of Set 1 | butaritari
# Cannot find the following city: tsihombe
# Processing Record 168 of Set 1 | port lincoln
# Processing Record 169 of Set 1 | nushki
# Cannot find the following city: grand river south east
# Processing Record 170 of Set 1 | samarai
# Cannot find the following city: warqla
# Processing Record 171 of Set 1 | norman wells
# Processing Record 172 of Set 1 | hasaki
# Processing Record 173 of Set 1 | pangnirtung
# Processing Record 174 of Set 1 | humaita
# Processing Record 175 of Set 1 | lata
# Processing Record 176 of Set 1 | saveh
# Processing Record 177 of Set 1 | tevaitoa
# Processing Record 178 of Set 1 | tura
# Processing Record 179 of Set 1 | dosso
# Processing Record 180 of Set 1 | luderitz
# Processing Record 181 of Set 1 | olinda
# Processing Record 182 of Set 1 | wanning
# Processing Record 183 of Set 1 | baruun-urt
# Processing Record 184 of Set 1 | saldanha
# Processing Record 185 of Set 1 | biak
# Processing Record 186 of Set 1 | lagoa
# Processing Record 187 of Set 1 | sinnamary
# Processing Record 188 of Set 1 | fukue
# Processing Record 189 of Set 1 | torbay
# Processing Record 190 of Set 1 | seoul
# Processing Record 191 of Set 1 | fallon
# Processing Record 192 of Set 1 | dikson
# Processing Record 193 of Set 1 | ponta do sol
# Processing Record 194 of Set 1 | khatanga
# Processing Record 195 of Set 1 | chaplygin
# Cannot find the following city: pribelskiy
# Processing Record 196 of Set 1 | jiwani
# Processing Record 197 of Set 1 | yima
# Processing Record 198 of Set 1 | christchurch
# Processing Record 199 of Set 1 | saint-raphael
# Processing Record 200 of Set 1 | chuy
# Processing Record 201 of Set 1 | yurimaguas
# Processing Record 202 of Set 1 | keti bandar
# Processing Record 203 of Set 1 | sur
# Processing Record 204 of Set 1 | guerrero negro
# Processing Record 205 of Set 1 | port blair
# Processing Record 206 of Set 1 | farafangana
# Processing Record 207 of Set 1 | sao joao da barra
# Processing Record 208 of Set 1 | invermere
# Processing Record 209 of Set 1 | hirara
# Processing Record 210 of Set 1 | alta floresta
# Processing Record 211 of Set 1 | shu
# Processing Record 212 of Set 1 | dunmore town
# Processing Record 213 of Set 1 | port moresby
# Processing Record 214 of Set 1 | lamu
# Processing Record 215 of Set 1 | ferrol
# Processing Record 216 of Set 1 | airai
# Processing Record 217 of Set 1 | noumea
# Processing Record 218 of Set 1 | providencia
# Processing Record 219 of Set 1 | honiara
# Processing Record 220 of Set 1 | dudinka
# Processing Record 221 of Set 1 | narsaq
# Cannot find the following city: tabiauea
# Processing Record 222 of Set 1 | challans
# Processing Record 223 of Set 1 | tokur
# Processing Record 224 of Set 1 | sterling
# Processing Record 225 of Set 1 | dali
# Processing Record 226 of Set 1 | pryshyb
# Processing Record 227 of Set 1 | ranong
# Processing Record 228 of Set 1 | del rio
# Processing Record 229 of Set 1 | bichura
# Processing Record 230 of Set 1 | natori
# Processing Record 231 of Set 1 | comitan
# Cannot find the following city: kuhestan
# Processing Record 232 of Set 1 | santona
# Processing Record 233 of Set 1 | te anau
# Processing Record 234 of Set 1 | alofi
# Processing Record 235 of Set 1 | makaryev
# Processing Record 236 of Set 1 | koson
# Processing Record 237 of Set 1 | adrar
# Processing Record 238 of Set 1 | abu dhabi
# Cannot find the following city: phan rang
# Processing Record 239 of Set 1 | port hedland
# Processing Record 240 of Set 1 | rafraf
# Cannot find the following city: amderma
# Cannot find the following city: mrirt
# Processing Record 241 of Set 1 | coruripe
# Processing Record 242 of Set 1 | niamey
# Processing Record 243 of Set 1 | pisco
# Processing Record 244 of Set 1 | nemuro
# Processing Record 245 of Set 1 | esperance
# Processing Record 246 of Set 1 | richards bay
# Processing Record 247 of Set 1 | beian
# Processing Record 248 of Set 1 | dongning
# Processing Record 249 of Set 1 | santo augusto
# Processing Record 250 of Set 1 | port macquarie
# Cannot find the following city: vaitupu
# Processing Record 251 of Set 1 | jiazi
# Processing Record 252 of Set 1 | ossora
# Processing Record 253 of Set 1 | yinchuan
# Processing Record 254 of Set 1 | tigil
# Processing Record 255 of Set 1 | birin
# Processing Record 256 of Set 1 | kalmunai
# Processing Record 257 of Set 1 | marzuq
# Processing Record 258 of Set 1 | najran
# Processing Record 259 of Set 1 | kruisfontein
# Processing Record 260 of Set 1 | nogliki
# Processing Record 261 of Set 1 | jalingo
# Processing Record 262 of Set 1 | mayo
# Processing Record 263 of Set 1 | palmer
# Processing Record 264 of Set 1 | tessalit
# Processing Record 265 of Set 1 | xuddur
# Processing Record 266 of Set 1 | cherskiy
# Processing Record 267 of Set 1 | kamra
# Cannot find the following city: mentok
# Processing Record 268 of Set 1 | atikokan
# Processing Record 269 of Set 1 | lorengau
# Processing Record 270 of Set 1 | gernsbach
# Processing Record 271 of Set 1 | clyde river
# Processing Record 272 of Set 1 | caravelas
# Processing Record 273 of Set 1 | cidreira
# Cannot find the following city: bandar-e torkaman
# Processing Record 274 of Set 1 | deputatskiy
# Processing Record 275 of Set 1 | svetlogorsk
# Processing Record 276 of Set 1 | bethel
# Processing Record 277 of Set 1 | chokurdakh
# Processing Record 278 of Set 1 | taicheng
# Processing Record 279 of Set 1 | shadegan
# Processing Record 280 of Set 1 | kaufbeuren
# Processing Record 281 of Set 1 | gejiu
# Processing Record 282 of Set 1 | ternate
# Cannot find the following city: armacao dos buzios
# Processing Record 283 of Set 1 | nome
# Processing Record 284 of Set 1 | puerto escondido
# Processing Record 285 of Set 1 | berlevag
# Processing Record 286 of Set 1 | carutapera
# Processing Record 287 of Set 1 | bambous virieux
# Processing Record 288 of Set 1 | nantucket
# Processing Record 289 of Set 1 | palu
# Processing Record 290 of Set 1 | susangerd
# Processing Record 291 of Set 1 | gummidipundi
# Processing Record 292 of Set 1 | hamilton
# Processing Record 293 of Set 1 | westport
# Processing Record 294 of Set 1 | ceamurlia de jos
# Processing Record 295 of Set 1 | tokonou
# Processing Record 296 of Set 1 | havoysund
# Cannot find the following city: yithion
# Processing Record 297 of Set 1 | talnakh
# Processing Record 298 of Set 1 | bilma
# Processing Record 299 of Set 1 | cayenne
# Processing Record 300 of Set 1 | bay roberts
# Processing Record 301 of Set 1 | haines junction
# Processing Record 302 of Set 1 | harper
# Processing Record 303 of Set 1 | manokwari
# Processing Record 304 of Set 1 | ahuimanu
# Processing Record 305 of Set 1 | mirnyy
# Processing Record 306 of Set 1 | tiarei
# Processing Record 307 of Set 1 | tautira
# Cannot find the following city: borama
# Processing Record 308 of Set 1 | oliveira dos brejinhos
# Processing Record 309 of Set 1 | champerico
# Processing Record 310 of Set 1 | tuatapere
# Processing Record 311 of Set 1 | bathsheba
# Processing Record 312 of Set 1 | mitu
# Processing Record 313 of Set 1 | santiago del estero
# Processing Record 314 of Set 1 | san patricio
# Processing Record 315 of Set 1 | sao jose da coroa grande
# Processing Record 316 of Set 1 | stromness
# Processing Record 317 of Set 1 | magadan
# Processing Record 318 of Set 1 | dunedin
# Processing Record 319 of Set 1 | opuwo
# Processing Record 320 of Set 1 | arlit
# Cannot find the following city: jabiru
# Processing Record 321 of Set 1 | carolina
# Processing Record 322 of Set 1 | biltine
# Processing Record 323 of Set 1 | genhe
# Processing Record 324 of Set 1 | arnprior
# Processing Record 325 of Set 1 | souillac
# Processing Record 326 of Set 1 | lalin
# Processing Record 327 of Set 1 | berberati
# Processing Record 328 of Set 1 | tual
# Processing Record 329 of Set 1 | fairbanks
# Cannot find the following city: marcona
# Processing Record 330 of Set 1 | nyandoma
# Processing Record 331 of Set 1 | west wendover
# Processing Record 332 of Set 1 | adelaide
# Cannot find the following city: baboua
# Cannot find the following city: mergui
# Processing Record 333 of Set 1 | asmar
# Processing Record 334 of Set 1 | shingu
# Processing Record 335 of Set 1 | aswan
# Processing Record 336 of Set 1 | provideniya
# Processing Record 337 of Set 1 | labuhan
# Processing Record 338 of Set 1 | loubomo
# Processing Record 339 of Set 1 | chirongui
# Processing Record 340 of Set 1 | riosucio
# Processing Record 341 of Set 1 | yugorsk
# Processing Record 342 of Set 1 | abilene
# Processing Record 343 of Set 1 | pattani
# Processing Record 344 of Set 1 | yangambi
# Processing Record 345 of Set 1 | abay
# Processing Record 346 of Set 1 | sawai madhopur
# Processing Record 347 of Set 1 | san andres
# Processing Record 348 of Set 1 | klyuchi
# Processing Record 349 of Set 1 | owando
# Processing Record 350 of Set 1 | mogadishu
# Processing Record 351 of Set 1 | cabedelo
# Processing Record 352 of Set 1 | aurdal
# Processing Record 353 of Set 1 | barmer
# Processing Record 354 of Set 1 | marsa matruh
# Processing Record 355 of Set 1 | sanguem
# Processing Record 356 of Set 1 | monki
# Processing Record 357 of Set 1 | riyadh
# Processing Record 358 of Set 1 | zarubino
# Processing Record 359 of Set 1 | camacha
# Processing Record 360 of Set 1 | hay river
# Processing Record 361 of Set 1 | lubyany
# Processing Record 362 of Set 1 | waipawa
# Processing Record 363 of Set 1 | tari
# Processing Record 364 of Set 1 | daru
# Processing Record 365 of Set 1 | sumbe
# Processing Record 366 of Set 1 | qaqortoq
# Processing Record 367 of Set 1 | laizhou
# Processing Record 368 of Set 1 | albanel
# Processing Record 369 of Set 1 | baoro
# Processing Record 370 of Set 1 | yerbogachen
# Processing Record 371 of Set 1 | piacabucu
# Processing Record 372 of Set 1 | kathmandu
# Processing Record 373 of Set 1 | barcelos
# Processing Record 374 of Set 1 | izumo
# Processing Record 375 of Set 1 | katsuura
# Processing Record 376 of Set 1 | salinas
# Cannot find the following city: tocantinopolis
# Processing Record 377 of Set 1 | zhenlai
# Processing Record 378 of Set 1 | nishihara
# Processing Record 379 of Set 1 | tongchuan
# Processing Record 380 of Set 1 | leshukonskoye
# Cannot find the following city: tumannyy
# Processing Record 381 of Set 1 | kununurra
# Processing Record 382 of Set 1 | serenje
# Processing Record 383 of Set 1 | imperial
# Processing Record 384 of Set 1 | kirakira
# Processing Record 385 of Set 1 | denton
# Processing Record 386 of Set 1 | raudeberg
# Processing Record 387 of Set 1 | vanimo
# Processing Record 388 of Set 1 | dingle
# Processing Record 389 of Set 1 | sabang
# Processing Record 390 of Set 1 | teknaf
# Processing Record 391 of Set 1 | vestmannaeyjar
# Processing Record 392 of Set 1 | zaraza
# Processing Record 393 of Set 1 | belyy yar
# Processing Record 394 of Set 1 | bela
# Processing Record 395 of Set 1 | nisia floresta
# Processing Record 396 of Set 1 | vao
# Processing Record 397 of Set 1 | siljan
# Processing Record 398 of Set 1 | hervey bay
# Processing Record 399 of Set 1 | mendi
# Processing Record 400 of Set 1 | bambanglipuro
# Processing Record 401 of Set 1 | poum
# Processing Record 402 of Set 1 | manoel urbano
# Processing Record 403 of Set 1 | marsh harbour
# Processing Record 404 of Set 1 | presidente dutra
# Processing Record 405 of Set 1 | seymchan
# Processing Record 406 of Set 1 | srandakan
# Processing Record 407 of Set 1 | plavinas
# Processing Record 408 of Set 1 | hollola
# Processing Record 409 of Set 1 | balarampur
# Processing Record 410 of Set 1 | broken hill
# Processing Record 411 of Set 1 | campo maior
# Processing Record 412 of Set 1 | moss vale
# Processing Record 413 of Set 1 | santiago de cuba
# Processing Record 414 of Set 1 | lago da pedra
# Processing Record 415 of Set 1 | broome
# Processing Record 416 of Set 1 | rovaniemi
# Processing Record 417 of Set 1 | fayaoue
# Processing Record 418 of Set 1 | shizunai
# Cannot find the following city: sataua
# Processing Record 419 of Set 1 | verkhoyansk
# Processing Record 420 of Set 1 | namatanai
# Processing Record 421 of Set 1 | bellefontaine
# Processing Record 422 of Set 1 | baherden
# Processing Record 423 of Set 1 | pemangkat
# Processing Record 424 of Set 1 | sulzbach-rosenberg
# Processing Record 425 of Set 1 | ilulissat
# Processing Record 426 of Set 1 | hambantota
# Processing Record 427 of Set 1 | ludwigslust
# Cannot find the following city: toliary
# Cannot find the following city: kankavli
# Processing Record 428 of Set 1 | coolum beach
# Processing Record 429 of Set 1 | yeppoon
# Processing Record 430 of Set 1 | vestmanna
# Processing Record 431 of Set 1 | teguise
# Processing Record 432 of Set 1 | anchorage
# Processing Record 433 of Set 1 | tefe
# Processing Record 434 of Set 1 | musoma
# Processing Record 435 of Set 1 | acajutla
# Processing Record 436 of Set 1 | luganville
# Processing Record 437 of Set 1 | talcahuano
# Processing Record 438 of Set 1 | fare
# Processing Record 439 of Set 1 | duldurga
# Processing Record 440 of Set 1 | san rafael
# Processing Record 441 of Set 1 | sarahan
# Processing Record 442 of Set 1 | aklavik
# Processing Record 443 of Set 1 | kabalo
# Cannot find the following city: dien bien
# Processing Record 444 of Set 1 | sioux lookout
# Processing Record 445 of Set 1 | jining
# Processing Record 446 of Set 1 | ishigaki
# Processing Record 447 of Set 1 | nabire
# Processing Record 448 of Set 1 | rey bouba
# Processing Record 449 of Set 1 | cotonou
# Processing Record 450 of Set 1 | gorontalo
# Processing Record 451 of Set 1 | alvorada
# Processing Record 452 of Set 1 | pirgos
# Processing Record 453 of Set 1 | miri
# Processing Record 454 of Set 1 | kamaishi
# Processing Record 455 of Set 1 | lamar
# Processing Record 456 of Set 1 | chhabra
# Processing Record 457 of Set 1 | lagoa formosa
# Processing Record 458 of Set 1 | ulladulla
# Processing Record 459 of Set 1 | olga
# Processing Record 460 of Set 1 | isangel
# Processing Record 461 of Set 1 | atambua
# Processing Record 462 of Set 1 | suntar
# Processing Record 463 of Set 1 | mariental
# Processing Record 464 of Set 1 | sao miguel do araguaia
# Processing Record 465 of Set 1 | langxiang
# Cannot find the following city: ust-kamchatsk
# Processing Record 466 of Set 1 | iwanai
# Processing Record 467 of Set 1 | savalou
# Processing Record 468 of Set 1 | pandamatenga
# Processing Record 469 of Set 1 | kommunar
# Processing Record 470 of Set 1 | port-gentil
# Processing Record 471 of Set 1 | saint anthony
# Processing Record 472 of Set 1 | liverpool
# Cannot find the following city: umzimvubu
# Processing Record 473 of Set 1 | paamiut
# Processing Record 474 of Set 1 | gat
# Cannot find the following city: safwah
# Processing Record 475 of Set 1 | weiser
# Processing Record 476 of Set 1 | wadi musa
# Processing Record 477 of Set 1 | ghanzi
# Processing Record 478 of Set 1 | komsomolskiy
# Processing Record 479 of Set 1 | mandaguacu
# Processing Record 480 of Set 1 | raymondville
# Processing Record 481 of Set 1 | severo-yeniseyskiy
# Processing Record 482 of Set 1 | touzim
# Processing Record 483 of Set 1 | laramie
# Processing Record 484 of Set 1 | lulea
# Processing Record 485 of Set 1 | semypolky
# Processing Record 486 of Set 1 | hami
# Processing Record 487 of Set 1 | waddan
# Processing Record 488 of Set 1 | bandrele
# Processing Record 489 of Set 1 | itoman
# Cannot find the following city: meinung

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": new_cities_there,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp, 
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
weather_data.to_csv('weather_data.csv')

# %%
summary_data = weather_data.agg(['count','mean', 'std','min', 'max'])
#,'25%', '50%', '75%','max'
summary_data.head()
# Out:
#           City         Lat         Lng    Max Temp    Humidity  Cloudiness  \
# count      489  489.000000  489.000000  489.000000  489.000000  489.000000
# min       abay  -54.800000 -175.200000    1.200000    1.000000    0.000000
# max    zhenlai   78.218600  179.316700   44.140000  100.000000  100.000000
# mean       NaN   19.110611   23.696561   21.107894   71.554192   55.458078
# std        NaN   33.183576   91.972656    8.109518   20.096122   39.597343
#
#        Wind Speed Country          Date
# count  489.000000     489  4.890000e+02
# min      0.000000      AE  1.627427e+09
# max     12.830000      ZM  1.627428e+09
# mean     3.542536     NaN  1.627427e+09
# std      2.494962     NaN  8.970102e+01

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
new_weather_df = weather_data[weather_data.Humidity <= 100]
new_summary_table = new_weather_df.agg(['count','mean', 'std','min', 'max'])
new_weather_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        karratha -20.7377  116.8463     20.04        71           6
# 1      coahuayana  18.7333 -103.6833     30.71        72          64
# 2       grindavik  63.8424  -22.4338     11.61        93           0
# 3       inhambane -23.8650   35.3833     18.08        64           0
# 4  severo-kurilsk  50.6789  156.1250     14.04        95         100
#
#    Wind Speed Country        Date
# 0        2.54      AU  1627427466
# 1        2.72      MX  1627427467
# 2        5.66      IS  1627427467
# 3        3.35      MZ  1627427467
# 4        2.67      RU  1627427264

# %%
new_summary_table.head()
# Out:
#           City         Lat         Lng    Max Temp    Humidity  Cloudiness  \
# count      489  489.000000  489.000000  489.000000  489.000000  489.000000
# min       abay  -54.800000 -175.200000    1.200000    1.000000    0.000000
# max    zhenlai   78.218600  179.316700   44.140000  100.000000  100.000000
# mean       NaN   19.110611   23.696561   21.107894   71.554192   55.458078
# std        NaN   33.183576   91.972656    8.109518   20.096122   39.597343
#
#        Wind Speed Country          Date
# count  489.000000     489  4.890000e+02
# min      0.000000      AE  1.627427e+09
# max     12.830000      ZM  1.627428e+09
# mean     3.542536     NaN  1.627427e+09
# std      2.494962     NaN  8.970102e+01

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_axis = new_weather_df["Lat"]
plt.scatter(x_axis, new_weather_df["Max Temp"], marker="o", facecolors="blue", edgecolors="black",s=x_axis, alpha=0.75)
plt.title("City Latitude vs. Max Temperature (07/26/21)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.show()
# Out:
# C:\Users\esthe\anaconda3\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ## Observations
# Temperature increases from 0 to 35 latitude and decreases from 35 onwards. Also the data has a parabolic trend.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(x_axis, new_weather_df["Humidity"], marker="o", facecolors="blue", edgecolors="black",s=x_axis, alpha=0.75)
plt.title("City Latitude vs. Humidity (07/26/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()

# %% [markdown]
# ##Observations: The graph above is analyzing the humidity in comparison to the cities from which humidity data could be retrieved. There is a great variation of data with a high concentration of datapoints above 60% humidity and 40 latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(x_axis, new_weather_df["Cloudiness"], marker="o", facecolors="blue", edgecolors="black",s=x_axis, alpha=0.75)
plt.title("City Latitude vs. Cloudiness (07/26/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %% [markdown]
# ##Observations: The data comparing city latitude with cloudiness is widespread. However, there are clusters at both a cloudiness of 100 and that close to 0

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(x_axis, new_weather_df["Wind Speed"], marker="o", facecolors="blue", edgecolors="black",s=x_axis, alpha=0.75)
plt.title("City Latitude vs. Wind Speed (07/26/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()

# %% [markdown]
# ##Observations: In the scatterplot above analyzing city latitude with wind speed, most of the datapoints are clustering around windspeeds from 0 to 4 mph

# %% [markdown]
# ## Linear Regression

# %%
northern_weather_df = new_weather_df[new_weather_df.Lat >= 0]
southern_weather_df = new_weather_df[new_weather_df.Lat < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_x = northern_weather_df["Lat"]
approx_north = []
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_x, northern_weather_df["Max Temp"])
#regress_values = weight * slope + intercept
for w in north_x:
    approx_north.append(w*slope + intercept)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_x, northern_weather_df["Max Temp"])
plt.plot(north_x,approx_north,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print("The linear regression model is " + line_eq)
plt.savefig('north_temp.png')
plt.show()
# Out:
# The r-squared is: 0.404493211326441
# The linear regression model is y = -0.27x + 32.7

# %% [markdown]
# ##Observations: There is a rise in max temperature from 0 to around 35 latitude before a descent in temperature

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_x = southern_weather_df["Lat"]
approx_south = []
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_x, southern_weather_df["Max Temp"])
#regress_values = weight * slope + intercept
for w in south_x:
    approx_south.append(w*slope + intercept)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_x, southern_weather_df["Max Temp"])
plt.plot(south_x,approx_south,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print("The linear regression model is " + line_eq)
plt.savefig('south_temp.png')
plt.show()
# Out:
# The r-squared is: 0.6355318069415374
# The linear regression model is y = 0.43x + 27.25

# %% [markdown]
# ##Observation There is a clear rise in maximum temperature when the latitude approaches 0

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_x = northern_weather_df["Lat"]
approx_north = []
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_x, northern_weather_df["Humidity"])
#regress_values = weight * slope + intercept
for w in north_x:
    approx_north.append(w*slope + intercept)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_x, northern_weather_df["Humidity"])
plt.plot(north_x,approx_north,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print("The linear regression model is " + line_eq)
plt.savefig('north_hum.png')
plt.show()
# Out:
# The r-squared is: 0.0001392083153260217
# The linear regression model is y = 0.01x + 71.71

# %% [markdown]
# ##Observation: The majority of cities, regardless of latitude from 0 to 80, have a humidity above 0

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_x = southern_weather_df["Lat"]
approx_south = []
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_x, southern_weather_df["Humidity"])
#regress_values = weight * slope + intercept
for w in south_x:
    approx_south.append(w*slope + intercept)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_x, southern_weather_df["Humidity"])
plt.plot(south_x,approx_south,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print("The linear regression model is " + line_eq)
plt.savefig('south_hum.png')
plt.show()
# Out:
# The r-squared is: 0.0007010547473669116
# The linear regression model is y = 0.03x + 70.97

# %% [markdown]
# ##Observations: The values are almost evenly distributed in terms of humidity. Linear regression suggests a slight increase in humidity when approaching 0.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_x = northern_weather_df["Lat"]
approx_north = []
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_x, northern_weather_df["Cloudiness"])
#regress_values = weight * slope + intercept
for w in north_x:
    approx_north.append(w*slope + intercept)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_x, northern_weather_df["Cloudiness"])
plt.plot(north_x,approx_north,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print("The linear regression model is " + line_eq)
plt.savefig('north_cloud.png')
plt.show()
# Out:
# The r-squared is: 0.003376588590733828
# The linear regression model is y = -0.12x + 66.46

# %% [markdown]
# ##Observations: The values are almost evenly distributed in terms of cloudiness. Linear regression suggests a slight decrease in cloudiness when moving away from 0.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_x = southern_weather_df["Lat"]
approx_south = []
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_x, southern_weather_df["Cloudiness"])
#regress_values = weight * slope + intercept
for w in south_x:
    approx_south.append(w*slope + intercept)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_x, southern_weather_df["Cloudiness"])
plt.plot(south_x,approx_south,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print("The linear regression model is " + line_eq)
plt.savefig('south_cloud.png')
plt.show()
# Out:
# The r-squared is: 0.007197030976314441
# The linear regression model is y = 0.23x + 47.52

# %% [markdown]
# ##Observations: The values are almost evenly distributed in terms of cloudiness. Linear regression suggests a slight increase in cloudiness when moving towards 0.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_x = northern_weather_df["Lat"]
approx_north = []
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_x, northern_weather_df["Wind Speed"])
#regress_values = weight * slope + intercept
for w in north_x:
    approx_north.append(w*slope + intercept)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_x, northern_weather_df["Wind Speed"])
plt.plot(north_x,approx_north,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print("The linear regression model is " + line_eq)
plt.savefig('north_wind.png')
plt.show()
# Out:
# The r-squared is: 0.018091509887380043
# The linear regression model is y = -0.02x + 4.0

# %% [markdown]
# ##Observations: Regardless of latitude, cities are clustering around wind speeds from 0 to 4 mph. Linear regression suggests a slight decrease in wind speed as latitude increases

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_x = southern_weather_df["Lat"]
approx_south = []
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_x, southern_weather_df["Wind Speed"])
#regress_values = weight * slope + intercept
for w in south_x:
    approx_south.append(w*slope + intercept)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_x, southern_weather_df["Wind Speed"])
plt.plot(south_x,approx_south,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print("The linear regression model is " + line_eq)
plt.savefig('south_wind.png')
plt.show()
# Out:
# The r-squared is: 0.0675331558787036
# The linear regression model is y = -0.05x + 2.93

# %% [markdown]
# ##Observations: Linear regression suggests a slight decrease in wind speed as latitude increases

# %% [markdown]
# ## General Trends based on linear regression:
# Temperature increases as the latitude approaches 0. Humidity drops as latitude approachs 0. Wind speed continues to drop as latitude increases. Humidity continues to drop as latitude increases
